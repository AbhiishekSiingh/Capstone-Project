# %% [markdown]
# # Phase 1
# # ===============================================================

# %% [markdown]
# # Crime In india
# ### Link -
# https://en.wikipedia.org/wiki/Crime_in_India#:~:text=The%20violent%20crime%20rate%20(per,and%20Arunachal%20Pradesh%20(41.7).
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_crime_rate
#
# ## Literacy rate in india census 2021 and NSO survey
# https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate
#
# ## Area of Indian territory link
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
#
# ## population in india
# https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r"C:\Users\ASHISH\Desktop\Capstone Analysis.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0          State&Uts  Population_2021  Population_1951  \
# 0           1      A & N Islands           417036          31480.0
# 1           2     Andhra Pradesh         53903393       31115000.0
# 2           3  Arunachal Pradesh          1570458              NaN
# 3           4              Assam         35607039        8029100.0
# 4           5              Bihar        124799926       29085900.0
#
#    Population_1961  Population_1971  Population_1981  Population_1991  \
# 0          64160.0         115874.0         189496.0         281990.0
# 1       35983480.0       43502710.0       53551030.0       66508170.0
# 2         337300.0         468885.0         632502.0         865900.0
# 3       10837700.0       14625157.0       18041250.0       22414320.0
# 4       34841490.0       42126800.0       52303000.0       64531200.0
#
#    Population_2001  Population_2011  ...  Robbery Hit_&_Run  \
# 0         356650.0           379944  ...      0.5       0.7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      36 non-null     int64
#  1   State&Uts                       36 non-null     object
#  2   Population_2021                 36 non-null     int64
#  3   Population_1951                 34 non-null     float64
#  4   Population_1961                 35 non-null     float64
#  5   Population_1971                 35 non-null     float64
#  6   Population_1981                 35 non-null     float64
#  7   Population_1991                 35 non-null     float64
#  8   Population_2001                 35 non-null     float64
#  9   Population_2011                 36 non-null     int64
#  10  Area (km2)                      36 non-null     int64
#  11  Region                          36 non-null     object
# ...

# %%
print('Number of Rows :',df.shape[0])
print('Number of Columns :',df.shape[1])
# Out:
# Number of Rows : 36
# Number of Columns : 41

# %%
df.isin(['-']).sum()
# Out:
# Unnamed: 0                         0
# State&Uts                          0
# Population_2021                    0
# Population_1951                    0
# Population_1961                    0
# Population_1971                    0
# Population_1981                    0
# Population_1991                    0
# Population_2001                    0
# Population_2011                    0
# Area (km2)                         0
# Region                             0
# Area_Percentage                    0
# Literacy_rate_1951                15
# Literacy_rate_1961                 6
# Literacy_rate_1971                 1
# Literacy_rate_1981                 2
# Literacy_rate_1991                 1
# Literacy_rate_2001                 0
# Literacy_rate_2011                 0
# Crime_rate_2018                    2
# Crime_rate_2019                    2
# Crime_rate_2020                    0
# Crime_rate_2021                    0
# crime_density_2021                 0
# ...

# %%
df.replace('-',np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# State&Uts                          0
# Population_2021                    0
# Population_1951                    2
# Population_1961                    1
# Population_1971                    1
# Population_1981                    1
# Population_1991                    1
# Population_2001                    1
# Population_2011                    0
# Area (km2)                         0
# Region                             0
# Area_Percentage                    0
# Literacy_rate_1951                17
# Literacy_rate_1961                 8
# Literacy_rate_1971                 3
# Literacy_rate_1981                 4
# Literacy_rate_1991                 3
# Literacy_rate_2001                 2
# Literacy_rate_2011                 2
# Crime_rate_2018                    2
# Crime_rate_2019                    2
# Crime_rate_2020                    0
# Crime_rate_2021                    0
# crime_density_2021                 0
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State&Uts', 'Population_2021', 'Population_1951',
#        'Population_1961', 'Population_1971', 'Population_1981',
#        'Population_1991', 'Population_2001', 'Population_2011', 'Area (km2)',
#        'Region', 'Area_Percentage', 'Literacy_rate_1951', 'Literacy_rate_1961',
#        'Literacy_rate_1971', 'Literacy_rate_1981', 'Literacy_rate_1991',
#        'Literacy_rate_2001', 'Literacy_rate_2011', 'Crime_rate_2018',
#        'Crime_rate_2019', 'Crime_rate_2020', 'Crime_rate_2021',
#        'crime_density_2021', 'Violent_Crimes', 'Murder', 'Rape', 'Kidnapping',
#        'Crimes_Against_Children', 'Extortion', 'Robbery', 'Hit_&_Run',
#        'Drugs_Trafficking', 'Illegal_Arms', 'Avg_literacy_rate_2011',
#        'Male_literacy_rate', 'Female_literacy_rate',
#        'Average_NSO_literacy_rate_2017', 'Male_literacy_rate_2017',
#        'Female_literacy_rate_2017'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)

# %% [markdown]
# # Phase  2
# # ==============================================================

# %% [markdown]
# # <span style="color:orange">Exploratory Data Analysis <span style="color:orange">

# %% [markdown]
# ## <span style="color:red">2.1-	Analysis of Literacy Rate vs Total Crimes.<span style="color:red">
# # <span style="color:red">=================================<span style="color:red">

# %% [markdown]
# ## Literacy Rate According to Census from [1951-2011]

# %%
plt.figure(figsize=(25, 10))

# Plotting graph 📊 according to census
plt.plot(df['State&Uts'], df['Literacy_rate_1951'], marker='o', label='Literacy_rate_1951')
plt.plot(df['State&Uts'], df['Literacy_rate_1961'], marker='o', label='Literacy_rate_1961')
plt.plot(df['State&Uts'], df['Literacy_rate_1971'], marker='o', label='Literacy_rate_1971')
plt.plot(df['State&Uts'], df['Literacy_rate_1981'], marker='o', label='Literacy_rate_1981')
plt.plot(df['State&Uts'], df['Literacy_rate_1991'], marker='o', label='Literacy_rate_1991')
plt.plot(df['State&Uts'], df['Literacy_rate_2001'], marker='o', label='Literacy_rate_2001')
plt.plot(df['State&Uts'], df['Literacy_rate_2011'], marker='o', label='Literacy_rate_2011')

plt.xlabel('State&Uts',fontsize = 25)
plt.ylabel('Literacy Rate Over The Years ',fontsize = 25)
plt.title('Literacy Rate According To Census')
plt.xticks(fontsize=20,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## comment
# The literacy rate in India has shown significant improvement over the decades from the 1951 census to the 2011 census. Here's a brief overview of how the literacy rate has evolved during this period:
#
# 1. **1951 Census**: According to the 1951 census, the overall literacy rate in India was around 18.33%. At that time, the country was still grappling with widespread illiteracy, limited access to education, and socio-economic challenges.
#
# 2. **1971 Census**: By the 1971 census, the literacy rate had increased to approximately 29.45%. This increase was partly due to various educational initiatives undertaken by the government, including the establishment of schools and adult education programs.
#
# 3. **1991 Census**: In the 1991 census, the literacy rate further improved to around 52.21%. This period saw a significant expansion of educational infrastructure, increased investment in primary education, and awareness campaigns aimed at promoting literacy.
#
# 4. **2001 Census**: By the 2001 census, the literacy rate had climbed to about 64.84%. During this period, there was a growing emphasis on universal primary education, adult literacy programs, and the adoption of policies aimed at reducing gender disparities in education.
#
# 5. **2011 Census**: According to the 2011 census, the literacy rate in India reached approximately 74.04%. This marked a significant milestone in India's journey towards achieving higher levels of literacy. Factors contributing to this improvement included continued government investment in education, expansion of educational opportunities, and greater awareness about the importance of education.
#
# It's important to note that while there has been significant progress in improving literacy rates, challenges such as regional disparities, gender gaps, and quality of education still persist. The Indian government continues to prioritize education as a key area for development and has launched various initiatives to address these challenges and further enhance literacy rates across the country.

# %%
plt.figure(figsize = (15,5))
plt.title(" Literacy Rate 2011", fontsize=22, fontweight='bold')
a= sns.barplot(x = "State&Uts", y = "Avg_literacy_rate_2011", data = df,palette="deep")
a.set_xlabel('State&Uts',fontsize=20)
a.set_ylabel('Literacy Rate',fontsize=18)
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.title("Literacy Rate 2011 Vs Crime Density", fontsize=22, fontweight='bold')

# Create the bar plot
a = sns.barplot(x="State&Uts", y="crime_density_2021", data=df, palette="deep")
a.set_xlabel('State&Uts', fontsize=20)
a.set_ylabel('Literacy Rate', fontsize=18)
plt.xticks(fontsize=10, rotation=90)

# Overlay a line plot of another column
plt.plot(df['State&Uts'], df['Avg_literacy_rate_2011'], marker='o', color='red', label='literacy rate')

# You can adjust the parameters of the line plot (marker, color, label) as needed

plt.legend()  # Add legend for the line plot
plt.show()

# %% [markdown]
# ## NSO Survey Literacy Rate of 2017
#
#
# NSO regularly conducts surveys on various aspects of the Indian population, including education, employment, and health, specific surveys focused solely on literacy rates may not be conducted as frequently as the decennial census.

# %%
plt.figure(figsize = (12,5))
plt.title(" NSO Survey Literacy Rate of 2017", fontsize=22, fontweight='bold')
a= sns.barplot(x = "State&Uts", y = "Average_NSO_literacy_rate_2017", data = df)
a.set_xlabel('State&Uts',fontsize=20)
a.set_ylabel('Literacy Rate',fontsize=18)
plt.xticks(fontsize=10,rotation=90)
plt.show()

# %% [markdown]
# ## Male  & Female Literacy Rate in 2017

# %%
plt.figure(figsize = (16,6))
plt.plot(df['State&Uts'], df['Male_literacy_rate_2017'], marker='o', label='Male_literacy_rate_2017')
plt.plot(df['State&Uts'], df['Female_literacy_rate_2017'], marker='o', label='Female_literacy_rate_2017')
plt.xlabel('State&Uts',fontsize = 25)
plt.ylabel('Literacy Rate ',fontsize = 25)
plt.title('Male/Female Literacy Rate 2017')
plt.xticks(fontsize=18,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comment-
# * This data is NSO survey of 2017.
# * Female Literacy is High in Delhi in comparison to Male Literacy Rate in Delhi.
# * Kerala have highest Literacy Rate in comparison to all states. Male and Female almost equally literate.
# * Bihar , Rajasthan, Uttar Pradesh, Arunachal Pradesh have lowest Literacy Rate.
# * We don't have ladak data. Because This Union Territories' created in 2019

# %% [markdown]
# # <span style="color:red">2.2	 Analysis of the type of crime vs each state vs Literacy rate.<span style="color:red">
#
#
# ### Types of Crime In INDIA

# %%
plt.figure(figsize = (26,10))
plt.plot(df['State&Uts'], df['Violent_Crimes'], marker='o', label='Violent_Crimes')
plt.plot(df['State&Uts'], df['Murder'], marker='o', label='Murder')
plt.plot(df['State&Uts'], df['Rape'], marker='o', label='Rape')
plt.plot(df['State&Uts'], df['Kidnapping'], marker='o', label='Kidnapping')
plt.plot(df['State&Uts'], df['Crimes_Against_Children'], marker='o', label='Crimes_Against_Children')
plt.plot(df['State&Uts'], df['Extortion'], marker='o', label='Extortion')
plt.plot(df['State&Uts'], df['Robbery'], marker='o', label='Robbery')
plt.plot(df['State&Uts'], df['Hit_&_Run'], marker='o', label='Hit_&_Run')
plt.plot(df['State&Uts'], df['Drugs_Trafficking'], marker='o', label='Drugs_Trafficking')
plt.plot(df['State&Uts'], df['Illegal_Arms'], marker='o', label='Illegal_Arms')


# Literacy Rate according to 2017 NSo(National Statistical Organisation).
plt.plot(df['State&Uts'], df['Average_NSO_literacy_rate_2017'], marker='o', label='Average_NSO_literacy_rate_2017',linewidth=5)

plt.xlabel('State&Uts',fontsize = 25)
plt.ylabel('Crimes ',fontsize = 25)
plt.title('Type of Crimes',fontsize= 25)
plt.xticks(fontsize=18,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comment -
# * Here we can see that Crime Against Children is all time High in all most all states. In [Andman & Nicobar, Delhi,Sikkim,Haryana,Chandigarh, Madhya pradesh, Chhattisgarh,Maharashtra and Lakshadweep]. high an average in comparision to rest of states.
# * illegal Arms case is high in Uttarpradesh & uttrakhand.
# * Violent crime is all time high in all states.[ Assam, Delhi, Odisha & Haryana] have high rates of crime.
# * Kidnapping is Highest in Delhi.

# %% [markdown]
# ## Crime Density in 2021 vs Average Literacy Rate

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['crime_density_2021'], marker='o', label='crime_density_2021')
plt.plot(df['State&Uts'], df['Average_NSO_literacy_rate_2017'], marker='o', label='Average_NSO_literacy_rate_2017',linewidth=2)
plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime_density ',fontsize = 16)
plt.title('crime_density_2021')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comment -
# * Crime Density is Highest in Delhi.
# * Top 5 State&UTs is [Delhi, kerala, Tamil Nadu, Puducherry, chandigarh ] in Crime Rate Density.

# %% [markdown]
# # <span style="color:red">2.3	Analysis of year-on-year total crime rate.<span style="color:red">

# %% [markdown]
# ## Crime Rate Of Year [2018,2019,2020,2021] Vs Literacy Rate

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['Crime_rate_2018'], marker='o', label='Crime_rate_2018')
plt.plot(df['State&Uts'], df['Crime_rate_2019'], marker='o', label='Crime_rate_2019')
plt.plot(df['State&Uts'], df['Crime_rate_2020'], marker='o', label='Crime_rate_2020')
plt.plot(df['State&Uts'], df['Crime_rate_2021'], marker='o', label='Crime_rate_2021')


plt.plot(df['State&Uts'], df['Average_NSO_literacy_rate_2017'], marker='o', label='Average_NSO_literacy_rate_2017',linewidth=5)

plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime Rate ',fontsize = 16)
plt.title('crime_Rate Over The Years Vs Average Literacy Rate 2017')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## comment - This  Crime report of INDIA is given by NCRB's.
# 2018: According to the NCRB's "Crime in India" report for the year 2018, the total number of reported crimes in India increased compared to the previous year. Crimes such as murder, kidnapping, robbery, and cybercrime showed varying trends across different states and union territories.
#
# 2019: The NCRB's report for 2019 indicated a continuation of the trend observed in 2018, with an overall increase in reported crimes. However, specific crime categories and their rates may have fluctuated from year to year.
#
# 2020: The COVID-19 pandemic had a significant impact on various aspects of life, including crime rates. During the pandemic, lockdowns and restrictions may have influenced crime patterns, with changes observed in certain types of crimes such as theft, domestic violence, and cybercrime. However, official data specifically for 2020 may need to be analyzed to understand the full extent of these changes.
#
# 2021: Crime data for 2021 may not be fully available or analyzed yet, as data collection and reporting often take time. However, it's possible that the trends observed during the pandemic continued to influence crime rates, with potential shifts in patterns as the situation evolved.

# %% [markdown]
# * literacy rates may have some influence on crime rates, it's crucial to consider the complex interplay of various social, economic, cultural, and institutional factors that contribute to crime dynamics. Other factors such as poverty, inequality, unemployment, access to justice, law enforcement effectiveness, social cohesion, and cultural norms can also significantly impact crime rates.

# %% [markdown]
# # <span style="color:red">2.4	 Analysis of area vs overall crime.<span style="color:red">

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['crime_density_2021'], marker='o', label='crime_density_2021')


plt.plot(df['State&Uts'], df['Area (km2)'], marker='o', label='Area',linewidth=3)

plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime Rate ',fontsize = 16)
plt.title('crime_Rate Over The Years Vs Area')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Comment -
# * Area are not related to Crime anymore.
# * But in Delhi Area is very Less Instead Crime rate is very high. Because Population Density is Also factor.

# %% [markdown]
# # <span style="color:red">2.5	 Analysis of Population vs overall Crime.<span style="color:red">

# %%
plt.figure(figsize = (12,4))
plt.plot(df['State&Uts'], df['crime_density_2021'], marker='o', label='crime_density_2021')


plt.plot(df['State&Uts'], df['Population_2021'], marker='o', label='Population',linewidth=3)

plt.xlabel('State&Uts',fontsize = 16)
plt.ylabel('crime Rate ',fontsize = 16)
plt.title('crime_Rate  Vs Population')
plt.xticks(fontsize=12,rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # <span style='color:red'>2.6	Each state crime report. <span style='color:red'>

# %% [markdown]
# Among states, Uttarpradesh has the highest crime rate, and Nagaland has the lowest crime rate in 2021.
# Overall, Delhi has the highest crime rate, and D&N Haveli and Daman & Diu has the lowest crime rate in 2021.
#
# * Violent crimes are particularly high in Eastern India, Northeast India, National Capital Region (India). Bihar, Jharkhand, Odisha, West Bengal, Assam, Tripura, Arunachal Pradesh, Delhi, Haryana, Maharashtra, and Madhya Pradesh have violent crime rate higher than the national average in 2021.
#
# * Jharkhand has the highest murder rate in 2021.
#
# * Chandigarh has the Highest Rape Rates in India
#
# * Rajasthan has the highest rape cases in 2021.
#
# * Delhi has the highest kidnapping and robbery rate in 2021.
#
# * Punjab has the highest government-sponsored drugs trafficking rate in 2021.
#
# * Uttar Pradesh has the highest illegal arms seizure rate in 2021.
#
# * Some causes of crimes are region specific. Insurgents committed 178 crimes in 2021, mostly in Manipur.
#
# * Left wing extremists committed 387 crimes in 2021, mostly in Chhattisgarh.
#
# * Terrorists committed 380 crimes in 2021, mostly in Jammu & Kashmir.
#
# * Gujarat has the highest investigation and charge-sheeting rate, while Manipur has the lowest investigation and charge-sheeting rate in 2021.
#
# * Mizoram has the highest conviction rate, while Lakshadweep has the lowest conviction rate in 2021.
